# %% [markdown]
# <a href="https://colab.research.google.com/github/AisahAlfiyatusR/Image_Retrieval/blob/main/opencv_basic/resize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Plant/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Plant

# %%
ls
# Out:
# Leaf/  leaf_new.jpg  Leaf.zip

# %%
import os
dataset = os.listdir('/content/drive/MyDrive/Plant/Leaf')
len(dataset)
# Out:
# 44

# %%
# import the necessary packages
import matplotlib.pyplot as plt
import argparse
import imutils
import cv2

# %%
# Make sure that paths already exist
path = '/content/drive/MyDrive/Plant/Leaf/q_aff_cerris/R_0Class1 (10).jpg'
image = cv2.imread(path)

plt.title('Original')
plt.imshow(image)
plt.show()

# %%
# let's resize our image to be 150 pixels wide, but in order to
# prevent our resized image from being skewed/distorted, we must
# first calculate the ratio of the *new* width to the *old* width
r = 150.0 / image.shape[1]
dim = (150, int(image.shape[0] * r))

# perform the actual resizing of the image
resized = cv2.resize(image, dim, interpolation=cv2.INTER_AREA)
plt.imshow(resized)
plt.title("Resized (Width")
# Out:
# Text(0.5, 1.0, 'Resized (Width')

# %%
# let's resize the image to have a width of 50 pixels, again keeping
# in mind the aspect ratio
r = 50.0 / image.shape[0]
dim = (int(image.shape[1] * r), 50)

# perform the resizing
resized = cv2.resize(image, dim, interpolation=cv2.INTER_AREA)
plt.imshow(resized)
plt.title("Resized (Height)")
# Out:
# Text(0.5, 1.0, 'Resized (Height)')

# %%
# calculating the ratio each and every time we want to resize an
# image is a real pain, so let's use the imutils convenience
# function which will *automatically* maintain our aspect ratio
# for us
resized = imutils.resize(image, width=100)
plt.imshow(resized)
plt.title("Resized via imutils")
# Out:
# Text(0.5, 1.0, 'Resized via imutils')

# %%
# construct the list of interpolation methods in OpenCV
methods = [
	("cv2.INTER_NEAREST", cv2.INTER_NEAREST),
	("cv2.INTER_LINEAR", cv2.INTER_LINEAR),
	("cv2.INTER_AREA", cv2.INTER_AREA),
	("cv2.INTER_CUBIC", cv2.INTER_CUBIC),
	("cv2.INTER_LANCZOS4", cv2.INTER_LANCZOS4)]

# loop over the interpolation methods
for (name, method) in methods:
	# increase the size of the image by 3x using the current
	# interpolation method
	print("[INFO] {}".format(name))
	resized = imutils.resize(image, width=image.shape[1] * 3,
		inter=method)
# Out:
# [INFO] cv2.INTER_NEAREST
# [INFO] cv2.INTER_LINEAR
# [INFO] cv2.INTER_AREA
# [INFO] cv2.INTER_CUBIC
# [INFO] cv2.INTER_LANCZOS4

# %%
plt.imshow(resized)
plt.title("Method: {}".format(name))
# Out:
# Text(0.5, 1.0, 'Method: cv2.INTER_LANCZOS4')
