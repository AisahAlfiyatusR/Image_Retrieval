# %% [markdown]
# <a href="https://colab.research.google.com/github/AisahAlfiyatusR/Image_Retrieval/blob/main/opencv_basic/masking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Plant/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Plant

# %%
ls
# Out:
# Leaf/  Leaf.zip

# %%
import os

dataset = os.listdir('/content/drive/MyDrive/Plant/Leaf')
len(dataset)
# Out:
# 44

# %%
# import the necessary packages
from matplotlib import pyplot as plt
import numpy as np
import argparse
import cv2

# %%
path = '/content/drive/MyDrive/Plant/Leaf/q_aff_cerris/R_0Class1 (10).jpg'
image = cv2.imread(path)
plt.title('Original')
plt.imshow(image)
plt.show()

# %%
mask = np.zeros(image.shape[:2], dtype='uint8')
cv2.rectangle(mask, (0, 90), (200, 150), 255, -1)
plt.imshow(mask)
plt.title('Rectangular Mask')
# Out:
# Text(0.5, 1.0, 'Rectangular Mask')

# %%
masked = cv2.bitwise_and(image, image, mask=mask)
plt.imshow(masked)
plt.title('Mask Applied To')
# Out:
# Text(0.5, 1.0, 'Mask Applied To')

# %%
# now, let's make a circular mask with a radius of 100 pixels and
# apply the mask again

mask = np.zeros(image.shape[:2], dtype="uint8")
cv2.circle(mask, (145, 200), 100, 255, -1)
masked = cv2.bitwise_and(image, image, mask=mask)

# show the output images
plt.imshow(mask)
plt.title('Circular Mask')
# Out:
# Text(0.5, 1.0, 'Circular Mask')

# %%
plt.imshow(masked)
plt.title('Mask Applied to Image')
# Out:
# Text(0.5, 1.0, 'Mask Applied to Image')
