# %% [markdown]
# <a href="https://colab.research.google.com/github/AisahAlfiyatusR/Image_Retrieval/blob/main/opencv_basic/read_write_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Plant/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Plant

# %%
ls
# Out:
# Leaf/  Leaf.zip

# %%
import os
dataset = os.listdir('/content/drive/MyDrive/Plant/Leaf')
len(dataset)
# Out:
# 44

# %%
# import the necessary packages
from matplotlib import pyplot as plt
import argparse
import cv2

# %%
path = '/content/drive/MyDrive/Plant/Leaf/q_aff_cerris/R_0Class1 (10).jpg'
image = cv2.imread(path)

plt.title('Original')
plt.imshow(image)
plt.show()

# %%
# load the image from disk via "cv2.imread" and then grab the spatial
# dimensions, including width, height, and number of channels
(h, w, c) = image.shape[:3]

# display the image width, height, and number of channels to our
# terminal
print("width: {} pixels".format(image.shape[1]))
print("height: {}  pixels".format(image.shape[0]))
print("channels: {}".format(image.shape[2]))
# Out:
# width: 256 pixels
# height: 256  pixels
# channels: 3

# %%
# show the image and wait for a keypress
plt.imshow(image)
plt.title('Image')

# save the image back to disk (OpenCV handles converting image
# filetypes automatically)
cv2.imwrite("leaf_new.jpg", image)
# Out:
# True
