# %% [markdown]
# <a href="https://colab.research.google.com/github/AisahAlfiyatusR/Image_Retrieval/blob/main/image_processing/ip_adapative_thresholding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Plant/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Plant

# %%
# !pip install opencv-python

# %%
# import the necessary packages
import matplotlib.pyplot as plt
import cv2

# %%
path = '/content/drive/MyDrive/Plant/Leaf/q_aff_cerris/R_0Class1 (10).jpg'
image = cv2.imread(path)

# %%
# convert the image to grayscale and blur it slightly
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blurred = cv2.GaussianBlur(gray, (7, 7), 0)

# %%
(T, threshInv) = cv2.threshold(blurred, 130, 155,
	cv2.THRESH_BINARY_INV)
plt.imshow(threshInv)
plt.title('Simple Thresholding')
# Out:
# Text(0.5, 1.0, 'Simple Thresholding')

# %%
# apply Otsu's automatic thresholding
(T, threshInv) = cv2.threshold(blurred, 0, 255,
	cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)
plt.imshow(threshInv)
plt.title("Otsu Thresholding")
# Out:
# Text(0.5, 1.0, 'Otsu Thresholding')

# %%
# instead of manually specifying the threshold value, we can use
# adaptive thresholding to examine neighborhoods of pixels and
# adaptively threshold each neighborhood
thresh = cv2.adaptiveThreshold(blurred, 255,
	cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY_INV, 21, 10)
plt.imshow(thresh)
plt.title("Mean Adaptive Thresholding")
# Out:
# Text(0.5, 1.0, 'Mean Adaptive Thresholding')

# %%
# perform adaptive thresholding again, this time using a Gaussian
# weighting versus a simple mean to compute our local threshold
# value
thresh = cv2.adaptiveThreshold(blurred, 255,
	cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV, 21, 4)
plt.imshow(thresh)
plt.title("Gaussian Adaptive Thresholding")
# Out:
# Text(0.5, 1.0, 'Gaussian Adaptive Thresholding')
